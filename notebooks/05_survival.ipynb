# %% [markdown]
# # 05 — Survival analysis (KM + Cox PH)
#
# ```bash
# python scripts/run_survival.py
# ```
#
# Uses `survival_time_days`, `event_observed` (1=closed, 0=open/censored).

# %%
import json
from pathlib import Path
from IPython.display import Image, display

ROOT = Path("..").resolve()
print(json.dumps(json.loads((ROOT / "docs/step7_survival.json").read_text()), indent=2))

# %%
p = ROOT / "reports/figures/09_km_by_complexity.png"
if p.exists():
    display(Image(filename=str(p)))
