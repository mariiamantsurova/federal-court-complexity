# %% [markdown]
# # 03 — Machine learning: Random Forest
#
# Predicts `log1p(los_days)` from complexity, case type, and judge.
#
# Run from terminal (faster):
# ```bash
# python scripts/run_ml.py
# ```

# %%
import json
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

ROOT = Path("..").resolve()
metrics = json.loads((ROOT / "docs" / "step5_ml.json").read_text())
metrics

# %%
fig_path = ROOT / "reports" / "figures" / "06_rf_feature_importance.png"
if fig_path.exists():
    display(plt.imread(fig_path))
    plt.axis("off")
else:
    print("Run: python scripts/run_ml.py")

# %% [markdown]
# ## Report takeaways
#
# - Compare `R2_log_scale` to regression M3 (~0.547)
# - Check `importance_by_group`: complexity vs judge vs case_type
# - Document in `docs/PROJECT_LOG.md` Step 5
